# %%
import requests
from urllib import parse
from pprint import pprint
import pandas as pd
import config
import numpy as np

input_data = 'data/cleaned_opendoar_data.csv'

df_all_data = pd.read_csv(input_data, header=0, index_col='system_metadata.id')
display(df_all_data)
# Out:
#                               organisation.url organisation.country  \
# system_metadata.id
# 2                         https://www.unisg.ch                   ch
# 3                          http://www.unibo.it                   it
# 5                    https://www.lincoln.ac.uk                   gb
# 7                        http://www.ifremer.fr                   fr
# 8                     https://www.ccsd.cnrs.fr                   fr
# ...                                        ...                  ...
# 10668               https://www.fh-joanneum.at                   at
# 10669                   https://www.tib.eu/en/                   de
# 10670                   https://www.ipb.ac.rs/                   rs
# 10672                     https://uksw.edu.pl/                   pl
# 10673                https://www.fleni.org.ar/                   ar
#
#                     repository_metadata.metadata_record_count  \
# system_metadata.id
# 2                                                     43608.0
# 3                                                      5058.0
# 5                                                     18422.0
# 7                                                     26734.0
# 8                                                      1787.0
# ...                                                       ...
# 10668                                                     NaN
# 10669                                                     NaN
# 10670                                                     NaN
# 10672                                                     NaN
# 10673                                                     NaN
#
#                                      repository_metadata.oai_url  \
# system_metadata.id
# 2                       https://www.alexandria.unisg.ch/cgi/oai2
# 3                               http://amsacta.unibo.it/cgi/oai2
# 5                         https://eprints.lincoln.ac.uk/cgi/oai2
# 7                   http://www.ifremer.fr/docelec/oai/OAIHandler
# 8                   https://api.archives-ouvertes.fr/oai/edutice
# ...                                                          ...
# 10668                                                        NaN
# 10669                                                        NaN
# 10670                   https://pub.ipb.ac.rs/server/oai/request
# 10672                                                        NaN
# 10673                                                        NaN
#
#                    repository_metadata.type  \
# system_metadata.id
# 2                             institutional
# 3                             institutional
# 5                             institutional
# 7                             institutional
# 8                             institutional
# ...                                     ...
# 10668                         institutional
# 10669                         institutional
# 10670                         institutional
# 10672                         institutional
# 10673                         institutional
#
#                                  repository_metadata.url  \
# system_metadata.id
# 2                        http://www.alexandria.unisg.ch/
# 3                                http://amsacta.unibo.it
# 5                          https://eprints.lincoln.ac.uk
# 7                             http://archimer.ifremer.fr
# 8                   http://edutice.archives-ouvertes.fr/
# ...                                                  ...
# 10668                   https://epub.fh-joanneum.at/FHJ/
# 10669                 https://service.tib.eu/ldmservice/
# 10670                             https://pub.ipb.ac.rs/
# 10672                    https://bazawiedzy.uksw.edu.pl/
# 10673                  https://repositorio.fleni.org.ar/
#
#                    repository_metadata.software.name  \
# system_metadata.id
# 2                                            eprints
# 3                                            eprints
# 5                                            eprints
# 7                                                NaN
# 8                                                hal
# ...                                              ...
# 10668                                          other
# 10669                                          other
# 10670                                         dspace
# 10672                                          other
# 10673                                         dspace
#
#                     repository_metadata.full_text_record_count  \
# system_metadata.id
# 2                                                          0.0
# 3                                                       4471.0
# 5                                                          NaN
# 7                                                          NaN
# 8                                                          0.0
# ...                                                        ...
# 10668                                                      NaN
# 10669                                                      NaN
# 10670                                                      NaN
# 10672                                                      NaN
# 10673                                                      NaN
#
#                                             system_metadata.uri  \
# system_metadata.id
# 2                       https://v2.sherpa.ac.uk/id/repository/2
# 3                       https://v2.sherpa.ac.uk/id/repository/3
# 5                       https://v2.sherpa.ac.uk/id/repository/5
# 7                       https://v2.sherpa.ac.uk/id/repository/7
# 8                       https://v2.sherpa.ac.uk/id/repository/8
# ...                                                         ...
# 10668               https://v2.sherpa.ac.uk/id/repository/10668
# 10669               https://v2.sherpa.ac.uk/id/repository/10669
# 10670               https://v2.sherpa.ac.uk/id/repository/10670
# 10672               https://v2.sherpa.ac.uk/id/repository/10672
# 10673               https://v2.sherpa.ac.uk/id/repository/10673
#
#                    repository_metadata.software.name_other
# system_metadata.id
# 2                                                      NaN
# 3                                                      NaN
# 5                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# ...                                                    ...
# 10668                                       Visual Library
# 10669                                                 CKAN
# 10670                                                  NaN
# 10672                                           Omega-Psir
# 10673                                                  NaN
#
# [5335 rows x 10 columns]

# %%
''' Pie chart of RIS types'''
vals = df_base.groupby("repository_metadata.software.name").size().sort_values()
print(vals)
    
vals.groupby(['repository_metadata.software.name']).sum().plot(kind='pie', y='repository_metadata.software.name')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_64582/535918132.py in <module>
#       1 ''' Pie chart of RIS types'''
# ----> 2 vals = df_base.groupby("repository_metadata.software.name").size().sort_values()
#       3 print(vals)
#       4
#       5 vals.groupby(['repository_metadata.software.name']).sum().plot(kind='pie', y='repository_metadata.software.name')
#
# NameError: name 'df_base' is not defined
